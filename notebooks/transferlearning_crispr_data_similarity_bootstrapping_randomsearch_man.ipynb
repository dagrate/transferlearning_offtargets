# %%
__date__='20211122'
__revised__='20220319'
__author__='Jeremy Charlier'
# append drive directory to python sys path
import sys
path_to_module = '' # write the path if needed
sys.path.append(path_to_module)

# %%
from simanalysis import similarityPipeline
from sklearn.metrics.pairwise import manhattan_distances as man_dist
#
similarityPipeline(man_dist)
# Out:
# bootstrapped data: listgarten_elevation_cd33.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 133.0
# negative samples: 117.0
#
# bootstrapped data: CIRCLE_seq_10gRNA_wholeDataset.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 247.0
# negative samples: 3.0
#
# bootstrapped data: SITE-Seq_offTarget_wholeDataset.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 246.0
# negative samples: 4.0
#
# bootstrapped data: listgarten_elevation_guideseq.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 248.0
# negative samples: 2.0
#
# bootstrapped data: Listgarten_22gRNA_wholeDataset.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 248.0
# negative samples: 2.0
#
# bootstrapped data: Kleinstiver_5gRNA_wholeDataset.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 248
# negative samples: 2
#
# bootstrapped data: listgarten_elevation_hmg.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 247.0
# negative samples: 3.0
#
# bootstrapped data: guideseq.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 234
# negative samples: 16
#
# --- DISTANCES COMPUTATION ----
#
#
# --- NMC 10---
#
# [25.624, 35.028, 36.248, 35.448, 34.904, 35.712, 34.248, 31.288]
# [35.056, 25.436, 38.352, 26.648, 39.616, 38.808, 38.856, 24.48]
# [36.008, 38.056, 25.112, 37.968, 40.032, 39.232, 38.152, 35.968]
# [34.832, 27.344, 37.096, 24.872, 39.328, 38.616, 37.392, 26.52]
# [34.808, 39.436, 40.168, 40.056, 30.728, 38.52, 39.64, 37.12]
# [34.744, 37.776, 38.92, 38.488, 38.416, 20.88, 38.488, 35.408]
# [34.088, 38.412, 37.776, 37.4, 39.368, 39.384, 23.808, 35.408]
# [30.848, 22.876, 35.064, 22.552, 36.408, 36.384, 34.592, 14.92]
#
# --- NMC 25---
#
# [20.936, 33.432, 34.496, 33.84, 33.064, 34.336, 32.64, 30.048]
# [32.4, 20.252, 34.896, 21.176, 37.328, 37.2, 36.344, 20.296]
# [34.048, 34.848, 19.592, 35.184, 37.904, 37.312, 36.304, 33.976]
# [32.824, 21.288, 34.024, 19.208, 36.92, 36.68, 35.672, 20.536]
# [32.824, 37.528, 38.208, 38.336, 24.648, 36.456, 37.568, 35.648]
# [32.248, 36.164, 36.792, 36.128, 36.2, 17.232, 36.648, 32.928]
# [31.728, 35.872, 35.192, 35.8, 37.48, 37.656, 18.32, 33.496]
# [29.16, 15.916, 32.352, 16.168, 34.232, 34.44, 32.32, 10.128]
#
# --- NMC 50---
#
# [17.184, 32.356, 33.432, 32.704, 31.8, 33.488, 31.4, 28.752]
# [31.488, 17.392, 33.576, 19.056, 36.272, 35.656, 35.24, 17.96]
# [32.896, 33.328, 16.608, 33.848, 36.704, 36.496, 34.744, 31.528]
# [31.464, 18.184, 32.48, 16.96, 35.608, 35.528, 34.0, 18.096]
# [31.872, 36.608, 36.864, 36.696, 19.32, 35.344, 36.44, 34.632]
# [30.712, 34.544, 35.24, 34.784, 34.68, 15.6, 35.216, 31.856]
# [30.544, 34.564, 34.32, 34.328, 36.064, 36.4, 14.392, 32.312]
# [28.072, 14.188, 30.896, 14.416, 32.712, 33.304, 30.992, 8.808]
#
# --- NMC 100---
#
# [12.952, 31.376, 32.496, 31.728, 30.632, 32.392, 30.64, 27.936]
# [30.568, 15.48, 32.296, 17.776, 35.184, 34.688, 34.048, 16.328]
# [31.776, 32.112, 15.128, 32.216, 35.872, 35.36, 33.856, 30.456]
# [30.752, 16.564, 31.624, 15.576, 34.84, 34.512, 33.304, 15.872]
# [30.4, 35.392, 36.048, 35.848, 16.936, 34.032, 35.176, 33.664]
# [29.256, 33.576, 34.256, 33.696, 33.52, 14.664, 33.616, 31.024]
# [29.312, 33.424, 33.056, 33.032, 35.032, 35.416, 12.296, 31.48]
# [27.104, 12.848, 29.944, 13.176, 31.904, 32.352, 29.944, 6.144]
#
# --- NMC 500---
#
# [6.48, 29.364, 30.768, 30.016, 28.872, 30.928, 28.632, 26.528]
# [28.448, 12.792, 29.816, 15.112, 32.64, 32.728, 32.008, 13.272]
# [30.256, 29.652, 12.472, 30.064, 33.616, 33.328, 31.76, 28.776]
# [28.68, 13.804, 28.872, 12.456, 32.336, 32.792, 30.848, 12.488]
# [28.568, 33.36, 33.712, 33.544, 13.464, 32.12, 33.192, 32.504]
# [27.368, 31.24, 32.168, 31.392, 31.24, 11.392, 31.304, 29.496]
# [27.072, 31.076, 30.784, 30.88, 32.576, 33.488, 9.056, 29.992]
# [25.384, 10.452, 27.624, 10.624, 29.536, 30.704, 27.624, 1.592]
#
# --- NMC 1000---
#
# [5.568, 28.58, 30.176, 29.424, 28.112, 30.256, 28.128, 26.152]
# [27.496, 11.52, 29.08, 14.296, 31.92, 32.024, 31.136, 12.824]
# [29.368, 29.084, 11.6, 29.392, 32.784, 32.568, 30.944, 28.56]
# [28.144, 12.736, 28.144, 11.368, 31.352, 31.936, 29.992, 11.904]
# [28.104, 32.672, 32.68, 32.768, 12.168, 31.56, 32.568, 32.112]
# [26.8, 30.492, 31.336, 30.688, 30.504, 10.264, 30.568, 29.248]
# [26.36, 30.2, 29.72, 30.184, 31.848, 32.816, 7.744, 29.576]
# [24.712, 9.444, 26.848, 9.688, 28.744, 29.864, 26.784, 0.376]
#
# --- NMC 2000---
#
# [4.128, 28.204, 29.568, 28.664, 27.464, 29.616, 27.672, 26.072]
# [26.992, 10.768, 28.304, 13.408, 30.984, 31.456, 30.288, 12.728]
# [29.016, 28.068, 10.408, 28.304, 31.84, 31.768, 30.464, 28.496]
# [27.624, 11.552, 27.312, 10.568, 30.552, 31.136, 29.32, 11.768]
# [27.552, 31.612, 31.84, 32.248, 11.2, 30.784, 31.968, 32.056]
# [26.072, 29.776, 30.6, 29.912, 29.792, 9.608, 29.664, 29.208]
# [25.752, 29.664, 29.28, 29.52, 31.36, 31.952, 6.144, 29.432]
# [24.224, 8.644, 25.896, 8.736, 27.944, 29.168, 25.688, 0.064]

# %%
similarityPipeline(man_dist, nmcs=[3000])
# Out:
# bootstrapped data: listgarten_elevation_cd33.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 133.0
# negative samples: 117.0
#
# bootstrapped data: CIRCLE_seq_10gRNA_wholeDataset.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 247.0
# negative samples: 3.0
#
# bootstrapped data: SITE-Seq_offTarget_wholeDataset.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 246.0
# negative samples: 4.0
#
# bootstrapped data: listgarten_elevation_guideseq.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 248.0
# negative samples: 2.0
#
# bootstrapped data: Listgarten_22gRNA_wholeDataset.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 248.0
# negative samples: 2.0
#
# bootstrapped data: Kleinstiver_5gRNA_wholeDataset.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 248
# negative samples: 2
#
# bootstrapped data: listgarten_elevation_hmg.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 247.0
# negative samples: 3.0
#
# bootstrapped data: guideseq.csv
# new boostrapped data shape: (250, 24, 7)
# positive samples: 234
# negative samples: 16
#
# --- DISTANCES COMPUTATION ----
#
#
# --- NMC 3000---
#
# [3.408, 27.8, 29.112, 28.408, 26.944, 29.296, 27.216, 26.12]
# [26.86, 10.192, 28.652, 13.556, 30.332, 30.884, 29.62, 13.604]
# [28.44, 27.5, 9.416, 27.84, 31.68, 31.232, 29.968, 28.352]
# [27.424, 10.956, 26.84, 9.664, 30.176, 31.0, 28.656, 11.936]
# [27.192, 30.836, 31.336, 31.184, 10.424, 30.688, 31.472, 31.424]
# [26.136, 29.576, 30.52, 29.592, 29.16, 8.76, 28.88, 29.456]
# [25.48, 29.188, 29.048, 29.168, 30.768, 31.936, 5.216, 29.056]
# [23.864, 8.3, 25.704, 8.216, 27.656, 28.984, 24.88, 0.0]
